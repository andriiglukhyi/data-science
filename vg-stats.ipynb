# %% [markdown]
# # Video Game Sales

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # read in the data file with pandas

# %%
df = pd.read_csv('./vgsales.csv')

# %%
df_pub = pd.DataFrame(df['Publisher'].groupby(df.Publisher).count()).sort_values('Publisher', ascending=False)
df_pub.head()
# Out:
#                               Publisher
# Publisher
# Electronic Arts                    1351
# Activision                          975
# Namco Bandai Games                  932
# Ubisoft                             921
# Konami Digital Entertainment        832

# %% [markdown]
# # What’s the most common platform

# %%
df_plat = pd.DataFrame(df['Platform'].groupby(df.Platform).count()).sort_values('Platform', ascending=False)
df_plat.head()
# Out:
#           Platform
# Platform
# DS            2163
# PS2           2161
# PS3           1329
# Wii           1325
# X360          1265

# %% [markdown]
# # most common genre

# %%
df_genre = pd.DataFrame(df['Genre'].groupby(df.Genre).count()).sort_values('Genre', ascending=False)
df_genre.head()
# Out:
#               Genre
# Genre
# Action         3316
# Sports         2346
# Misc           1739
# Role-Playing   1488
# Shooter        1310

# %% [markdown]
# # 20 highest grossing games

# %%
df_top20 = pd.DataFrame(df[['Name', 'Global_Sales']].head(20)).sort_values('Global_Sales', ascending=False)
df_top20
# Out:
#                                             Name  Global_Sales
# 0                                     Wii Sports         82.74
# 1                              Super Mario Bros.         40.24
# 2                                 Mario Kart Wii         35.82
# 3                              Wii Sports Resort         33.00
# 4                       Pokemon Red/Pokemon Blue         31.37
# 5                                         Tetris         30.26
# 6                          New Super Mario Bros.         30.01
# 7                                       Wii Play         29.02
# 8                      New Super Mario Bros. Wii         28.62
# 9                                      Duck Hunt         28.31
# 10                                    Nintendogs         24.76
# 11                                 Mario Kart DS         23.42
# 12                   Pokemon Gold/Pokemon Silver         23.10
# 13                                       Wii Fit         22.72
# ...

# %% [markdown]
# # median for NA games

# %%
na_med = np.median(df['NA_Sales'])
na_med
# Out:
# 0.08

# %%
df[df['NA_Sales']==na_med].head(10)
# Out:
#       Rank                                               Name Platform  \
# 446    447                                  Dragon Warrior IV      NES
# 497    498        World Soccer Winning Eleven 7 International      PS2
# 1617  1619                             Farming Simulator 2015       PC
# 1926  1928                          Pro Evolution Soccer 2008     X360
# 2067  2069  Winning Eleven: Pro Evolution Soccer 2007 (All...     X360
# 2373  2375                           Phantasy Star Portable 2      PSP
# 2579  2581                               The Sims 2: Castaway      PSP
# 3186  3188                                     SingStar Queen      PS2
# 3503  3505                                         Top Spin 3      PS3
# 3703  3705               Sonic & All-Stars Racing Transformed      PS3
#
#         Year         Genre                     Publisher  NA_Sales  EU_Sales  \
# 446   1990.0  Role-Playing              Enix Corporation      0.08      0.00
# ...

# %% [markdown]
# # top-selling game deviation

# %%
df_mean = np.mean(df['NA_Sales'])
df_std = pd.DataFrame(df[df.NA_Sales.values >= df_mean])
df_std.NA_Sales.std()
# Out:
# 1.5190362471782832

# %% [markdown]
# # The Nintendo Wii seems to have outdone itself with games. How does its average number of sales compare with all of the other platforms?

# %%
wii = df[['Platform', 'Global_Sales']].groupby('Platform')
wii = pd.DataFrame(wii['Global_Sales'].mean()).sort_values('Global_Sales', ascending=False)
wii.head()
# Out:
#           Global_Sales
# Platform
# GB            2.606633
# NES           2.561939
# GEN           1.050370
# SNES          0.837029
# PS4           0.827679
